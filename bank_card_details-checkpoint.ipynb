# %%
import pandas as pd
df = pd.read_csv('BankChurners.csv')
df.head()
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# 2        Graduate        Married    $80K - $120K          Blue
# 3     High School        Unknown  Less than $40K          Blue
# 4      Uneducated        Married     $60K - $80K          Blue
#
#    Months_on_book  ...  Credit_Limit  Total_Revolving_Bal  Avg_Open_To_Buy  \
# 0              39  ...       12691.0                  777          11914.0
# ...

# %%
df.info()
df.describe()
df.columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10127 entries, 0 to 10126
# Data columns (total 23 columns):
#  #   Column                                                                                                                              Non-Null Count  Dtype
# ---  ------                                                                                                                              --------------  -----
#  0   CLIENTNUM                                                                                                                           10127 non-null  int64
#  1   Attrition_Flag                                                                                                                      10127 non-null  object
#  2   Customer_Age                                                                                                                        10127 non-null  int64
# ...

# %% [markdown]
# ## Cleaning and Preprocessing

# %%
df_cleaned = df.drop(columns=[col for col in df.columns if "Naive_Bayes" in col])

# %%
df_cleaned.isnull().sum()
df_cleaned.duplicated().sum()
# Out:
# 0

# %%
df_cleaned['credit_utilization'] = df_cleaned['total_revolving_bal'] / df_cleaned['credit_limit']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'total_revolving_bal'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 1
# ...

# %%
df_cleaned.rename(columns=lambda x: x.strip().replace(" ", "_").lower(), inplace=True)

# %%
df_cleaned.rename(columns=lambda x: x.strip().replace(" ", "_").lower(),
                  inplace=True)

# %%
df_cleaned["credit_utilization"] = (
    df_cleaned["total_revolving_bal"] / df_cleaned["credit_limit"]
)

# %%
df_cleaned["credit_utilization"].describe()
# Out:
# count    10127.000000
# mean         0.274892
# std          0.275689
# min          0.000000
# 25%          0.022714
# 50%          0.175650
# 75%          0.502691
# max          0.998768
# Name: credit_utilization, dtype: float64

# %%
df_cleaned["high_util_flag"] = (df_cleaned["credit_utilization"] > 0.8).astype(int)

# %% [markdown]
# ## EXPLORATORY DATA ANALYSIS (EDA) (Seaborn, Matplotlib)

# %%
df_cleaned['attrition_flag'].value_counts(normalize=True).plot(kind='bar')
# Out:
# <Axes: xlabel='attrition_flag'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Churn vs. Utilization
sns.boxplot(x='attrition_flag', y='credit_utilization', data=df_cleaned)
plt.title('Credit Utilization by Customer Status')
plt.show()

# %%
# Monthly Transactions by Category
sns.histplot(df_cleaned['total_trans_ct'], kde=True)
plt.title('Distribution of Monthly Transactions per Customer')
plt.xlabel('Total Transactions in 12 Months')
plt.show()

# %%
sns.histplot(df_cleaned['credit_utilization'], bins=30, kde=True)
# Out:
# <Axes: xlabel='credit_utilization', ylabel='Count'>

# %%
sns.boxplot(data=df_cleaned, x='attrition_flag', y='months_inactive_12_mon')
# Out:
# <Axes: xlabel='attrition_flag', ylabel='months_inactive_12_mon'>

# %% [markdown]
# ## FEATURE ENGINEERING

# %%
df_cleaned['risk_flag'] = (
    (df_cleaned['credit_utilization'] > 0.8) &
    (df_cleaned['months_inactive_12_mon'] > 4)
).astype(int)

# %%
df_cleaned['risk_flag'].value_counts()
# Out:
# risk_flag
# 0    10102
# 1       25
# Name: count, dtype: int64

# %%
df_cleaned.groupby('risk_flag').mean(numeric_only=True)
# Out:
#               clientnum  customer_age  dependent_count  months_on_book  \
# risk_flag
# 0          7.391683e+08     46.322213         2.344981       35.920907
# 1          7.429287e+08     47.840000         2.840000       38.960000
#
#            total_relationship_count  months_inactive_12_mon  \
# risk_flag
# 0                           3.81172                2.333696
# 1                           4.16000                5.360000
#
#            contacts_count_12_mon  credit_limit  total_revolving_bal  \
# risk_flag
# 0                       2.456543    8647.30883          1160.474658
# 1                       1.960000    2427.25200          2108.120000
#
#            avg_open_to_buy  total_amt_chng_q4_q1  total_trans_amt  \
# risk_flag
# 0              7486.834171              0.759873      4406.188676
# 1               319.132000              0.787080      3554.560000
#
#            total_trans_ct  total_ct_chng_q4_q1  avg_utilization_ratio  \
# risk_flag
# ...

# %%
sns.countplot(x='Attrition_Flag', hue='risk_flag', data=df_cleaned)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 sns.countplot(x='Attrition_Flag', hue='risk_flag', data=df_cleaned)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\seaborn\categorical.py:2631, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, fill, hue_norm, stat, width, dodge, gap, log_scale, native_scale, formatter, legend, ax, **kwargs)
#    2628 elif x is not None and y is not None:
#    2629     raise TypeError("Cannot pass values for both `x` and `y`.")
# -> 2631 p = _CategoricalAggPlotter(
#    2632     data=data,
#    2633     variables=dict(x=x, y=y, hue=hue),
#    2634     order=order,
#    2635     orient=orient,
#    2636     color=color,
#    2637     legend=legend,
#    2638 )
#    2640 if ax is None:
#    2641     ax = plt.gca()
#
# ...

# %%
df_cleaned.columns
# Out:
# Index(['clientnum', 'attrition_flag', 'customer_age', 'gender',
#        'dependent_count', 'education_level', 'marital_status',
#        'income_category', 'card_category', 'months_on_book',
#        'total_relationship_count', 'months_inactive_12_mon',
#        'contacts_count_12_mon', 'credit_limit', 'total_revolving_bal',
#        'avg_open_to_buy', 'total_amt_chng_q4_q1', 'total_trans_amt',
#        'total_trans_ct', 'total_ct_chng_q4_q1', 'avg_utilization_ratio',
#        'credit_utilization', 'high_util_flag', 'risk_flag'],
#       dtype='object')

# %%
df_cleaned.rename(columns=lambda x: x.strip().replace(" ", "_").lower(), inplace=True)

# %%
sns.countplot(x='attrition_flag', hue='risk_flag', data=df_cleaned)
plt.title('Risk Flag Count by Customer Status')
plt.show()

# %%
df_cleaned.to_csv('Cleaned_BankChurners.csv', index=False)

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\Dell\Customer_Credit_Analysis
